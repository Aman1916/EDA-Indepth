# %% [markdown]
# # Bivariate Analysis & MultiVariate analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1=pd.read_csv('train.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 1. Scatter plot - (Numerical -Numerical)

# %%
sns.scatterplot(x=df["total_bill"],y=df["tip"],hue=df['smoker'],size=df['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. Bar plot (Numerical-Categorical)

# %%
sns.barplot(x=df1['Survived'],y=df1['Sex'])
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %%
sns.barplot(x=df1['Pclass'],y=df1['Fare'],hue=df1['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x=df1['Pclass'],y=df1['Age'],hue=df1['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=df1['Pclass'],y=df1['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=df1['Survived'],y=df1['Age'],saturation=4.75)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x=df1['Pclass'],y=df1['Age'],hue=df1['SibSp'],color="r")
# Out:
# C:\Users\Aman Patidar\AppData\Local\Temp\ipykernel_11632\2769015122.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.barplot(x=df1['Pclass'],y=df1['Age'],hue=df1['SibSp'],color="r")
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=df1['Pclass'],y=df1['Age'],hue=df1['Survived'],color="r",saturation=3.75)
# Out:
# C:\Users\Aman Patidar\AppData\Local\Temp\ipykernel_11632\3219851543.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.barplot(x=df1['Pclass'],y=df1['Age'],hue=df1['Survived'],color="r",saturation=3.75)
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.scatterplot(df['smoker'])
# Out:
# <Axes: ylabel='smoker'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x=df1['Pclass'],y=df1['Fare'],hue=df1["Sex"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x=df1['Pclass'],y=df1['Age'],hue=df1["Sex"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # Box Plot(Numerical -Categorical)

# %%
sns.boxplot(x=df1["Sex"],y=df1["Age"],hue=df1["Survived"])

# %% [markdown]
# # 4,Distplot(Numerical-Categoical)

# %%
sns.distplot(df1[df1["Survived"]==0]["Age"],hist=False)
sns.distplot(df1[df1["Survived"]==1]["Age"],hist=False)
# Out:
# C:\Users\Aman Patidar\AppData\Local\Temp\ipykernel_11632\2332788045.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[df1["Survived"]==0]["Age"],hist=False)
# C:\Users\Aman Patidar\AppData\Local\Temp\ipykernel_11632\2332788045.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # 5.Heatmap(Categorical-Categorical)

# %%
df1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
pd.crosstab(df1["Pclass"],df1["Survived"])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df1["Pclass"],df1["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
df1.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
df1.groupby(['Sex','Survived'])['Survived'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
df1.groupby(['Sex','Survived'])['Survived'].count().unstack('Sex')
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
df1.groupby(['Sex','Survived'])['Survived'].count().unstack(1)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
df1.groupby(['Embarked','Survived'])['Survived'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked,Survived'>

# %%
df1.groupby('Survived').agg(["count"])
# Out:
#          PassengerId Pclass  Name   Sex   Age SibSp Parch Ticket  Fare Cabin  \
#                count  count count count count count count  count count count
# Survived
# 0                549    549   549   549   424   549   549    549   549    68
# 1                342    342   342   342   290   342   342    342   342   136
#
#          Embarked
#             count
# Survived
# 0             549
# 1             340

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1.groupby('Pclass').mean()['Survived']*100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# ...

# %%
df1.groupby('Embarked').mean()['Survived']*100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# ...

# %% [markdown]
# # 6.ClusterMap(Categorical -Categorical)

# %%
pd.crosstab(df1['SibSp'],df1['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.heatmap(pd.crosstab(df1['SibSp'],df1['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='SibSp'>

# %%
sns.clustermap(pd.crosstab(df1["Parch"],df1["Survived"]))

# %% [markdown]
# # 7.Pairplot

# %%
# collection of scatter plots 
sns.pairplot(df1)

# %%
sns.pairplot(df,hue="sex")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # 8. Line plot(numeric-numeric)

# %%
# when x= time,date,year,month
df2 =sns.load_dataset("flights")

# %%
df2
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df2.groupby('year').sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df2.groupby('year').sum().reset_index()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:3053, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3048 else:
#    3049     # If we are grouping on categoricals we want unobserved categories to
#    3050     # return zero, rather than the default of NaN which the reindexing in
#    3051     # _agg_general() returns. GH #31422
#    3052     with com.temp_setattr(self, "observed", True):
# -> 3053         result = self._agg_general(
#    3054             numeric_only=numeric_only,
#    3055             min_count=min_count,
#    3056             alias="sum",
#    3057             npfunc=np.sum,
#    3058         )
#    3060     return self._reindex_output(result, fill_value=0)
#
# ...

# %%
sns.lineplot(x=df2['year'],y=df2['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
df2.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.heatmap(df2.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(df2.pivot_table(values='passengers',index='month',columns='year'))
